# %%
import pandas as pd

# %%
# !pip install pyarrow

# %%
data=pd.read_parquet('app_data_sample.parquet', engine='auto')

# %%
data.head(20)
# Out:
#    application_number filing_date examiner_name_last examiner_name_first  \
# 0            08284457  2000-01-26             HOWARD          JACQUELINE
# 1            08413193  2000-10-11           YILDIRIM               BEKIR
# 2            08531853  2000-05-17           HAMILTON             CYNTHIA
# 3            08637752  2001-07-20             MOSHER                MARY
# 4            08682726  2000-04-10               BARR             MICHAEL
# 5            08687412  2000-04-28               GRAY               LINDA
# 6            08716371  2004-01-26          MCMILLIAN                KARA
# 7            08765941  2000-06-23               FORD             VANESSA
# 8            08776818  2000-02-04         STRZELECKA              TERESA
# 9            08809677  2002-02-20                KIM                 SUN
# 10           08836939  2000-06-13               WOOD           ELIZABETH
# 11           08901519  2000-09-26               DENT               ALANA
# ...

# %%
data.to_csv('Data_CSV.csv')
